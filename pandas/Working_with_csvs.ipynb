# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#       Name  School  Marks
# 0  Shubham     SPS     34
# 1   Joshua     UPS     45
# 2     Jack     WPS     45
# 3     Alex     UIS     67
# 4  Jasmine     RTS     45
# 5    Rohan     RRY     88
# 6    Rishi  Luxury     77
# 7   Aakash     BBL     90

# %%
df = df[df['Marks']<60]

# %%
df
# Out:
#       Name School  Marks
# 0  Shubham    SPS     34
# 1   Joshua    UPS     45
# 2     Jack    WPS     45
# 4  Jasmine    RTS     45

# %%
#df.to_csv("data_updates.csv", index=False)

# %%
df = pd.read_json("data.json")

# %%
df
# Out:
#      name     lang                                            address
# 0    Asim   Python  {'post': 'kakrahawa bazar', 'city': 'Siddharth...
# 1  Mukesh  English  {'post': 'kakrahawa bazar', 'city': 'Siddharth...

# %%
data = [
  {
    "name": "Asim",
    "lang": "Python",
    "address": {
      "post": "Kakrahawa Bazar",
      "city": "Siddharth Nagar"
    }
  },
  {
    "name": "Mukesh",
    "lang": "English",
    "address": {
      "post": "Kakrahawa Bazar",
      "city": "Siddharth Nagar"
    }
  }
]

# %%
df = pd.json_normalize(data)

# %%
df
# Out:
#      name     lang     address.post     address.city
# 0    Asim   Python  Kakrahawa Bazar  Siddharth Nagar
# 1  Mukesh  English  Kakrahawa Bazar  Siddharth Nagar
