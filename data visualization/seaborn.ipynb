# %%
import seaborn as sns
import numpy as np

# %%
sns.set_theme(style="darkgrid")

# %%
x = np.array([1,23,4,5,6,43,65,67,63,4,3,79,32,12,45, 90])

# %%
y = np.sin(x)

# %%
sns.lineplot(x=x, y=y)
# Out:
# <Axes: >
