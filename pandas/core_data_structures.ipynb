# %%
import pandas as pd

# %%
s = pd.Series([71, 84, 38, 97, 45, 98, 83])

# %%
type(s)
# Out:
# pandas.Series

# %%
print(s)
# Out:
# 0    71
# 1    84
# 2    38
# 3    97
# 4    45
# 5    98
# 6    83
# dtype: int64

# %%
s1 = pd.Series([45, 56, 67], index = ["Asim", "Shahbaz", "Tuseef"])

# %%
s1
# Out:
# Asim       45
# Shahbaz    56
# Tuseef     67
# dtype: int64

# %%
data = {
    "name" : ["Alice", "Bob", "Charlie"],
    "age" : [25, 30, 35],
    "city" : ["Mumbai", "Lucknow", "Delhi"]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#       name  age     city
# 0    Alice   25   Mumbai
# 1      Bob   30  Lucknow
# 2  Charlie   35    Delhi

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['name', 'age', 'city'], dtype='str')
