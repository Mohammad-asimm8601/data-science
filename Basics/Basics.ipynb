# %%
a = 5

# %%
b = 7

# %%
a + b
# Out:
# 12

# %%
name = "Asim"

# %%
name
# Out:
# 'Asim'

# %%
type(name)
# Out:
# str

# %%
a = "2343"

# %%
b = "890"

# %%
print(a+b)
# Out:
# 2343890

# %%
int(a) + int(b)   #typecasing
# Out:
# 3233
