# %%
name = "Asim"

# %%
name
# Out:
# 'Asim'

# %%
name.upper()
# Out:
# 'ASIM'

# %%
name.endswith("im")
# Out:
# True

# %%
name.lower()
# Out:
# 'asim'

# %%
name.capitalize()
# Out:
# 'Asim'

# %%
name.count('a')
# Out:
# 0

# %%
name.strip()
# Out:
# 'Asim'

# %%
fruit = "mango, banana, grapes"
fruit.split()
# Out:
# ['mango,', 'banana,', 'grapes']

# %%
name[::-1]
# Out:
# 'misA'
