# %%
import json

# Function to load json data
def load_data(filename):
    with open("data.json") as f:
        return json.load(f)

# Funtion to find pages a user might like
def find_pages_you_might_like(user_id, data):
    # Dictonary to store user interactions with pages
    user_pages = {}
    # Populate the dictionary
    for user in data['users']:
        user_pages[user['id']] = set(user['liked_pages'])
    # If the user not found  return enpty list
    if user_id not in user_pages:
        return []
    user_liked_pages = user_pages[user_id]
    page_suggestion = {}

    for other_user, pages in user_pages.items():
        if other_user != user_id:
            shared_pages = user_liked_pages.intersection(pages)
        for page in pages:
            if page not in user_liked_pages:
                page_suggestion[page] = page_suggestion.get('get', 0) + len(shared_pages)
    sorted_pages = sorted(page_suggestion.items(), key=lambda x: x[1], reverse = True)
    return [page_id for page_id, _ in sorted_pages]
data = load_data("data.json")
user_id = 1
recc = find_pages_you_might_like(user_id, data)
print(recc)
# Out:
# [103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 119, 120, 121, 122, 123, 124, 125, 126, 127]
