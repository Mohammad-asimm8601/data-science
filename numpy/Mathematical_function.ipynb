# %%
import numpy as np

# %%
arr = np.array([3, 5, 2, 33])

# %%
np.mean(arr)
# Out:
# np.float64(10.75)

# %%
np.max(arr)
# Out:
# np.int64(33)

# %%
np.min(arr)
# Out:
# np.int64(2)

# %%
np.std(arr)
# Out:
# np.float64(12.891373084353738)

# %%
np.var(arr)
# Out:
# np.float64(166.1875)

# %%
np.sum(arr)
# Out:
# np.int64(43)

# %%
np.prod(arr)
# Out:
# np.int64(990)

# %%
np.median(arr)
# Out:
# np.float64(4.0)

# %%
np.percentile(arr, 50)
# Out:
# np.float64(4.0)

# %%
np.argmin(arr)
# Out:
# np.int64(2)

# %%
np.argmax(arr)
# Out:
# np.int64(3)

# %%
np.unique(arr)
# Out:
# array([ 2,  3,  5, 33])

# %%
np.diff(arr)
# Out:
# array([ 2, -3, 31])

# %%
np.cumsum(arr)
# Out:
# array([ 3,  8, 10, 43])
