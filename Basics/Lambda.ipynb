# %%
cube = lambda x : x*x*x

# %%
cube(4)
# Out:
# 64

# %%
num = [1, 2, 3, 4]
square = list(map(lambda x : x * x ,num))
print(square)
# Out:
# [False, True, False, True]

# %%
evens = list(filter(lambda x: x%2 == 0, num))
print(evens)
# Out:
# [2, 4]
